# %%
# List : List is just like array which is used to store a collection of data. Items in a list do not need to be of the same type.
courses = ['History', 'Math', 'Physics', 'Chemistry']
print(courses)
# Out:
# ['History', 'Math', 'Physics', 'Chemistry']

# %%
# Access specific element in list
courses = ['History', 'Math', 'Physics', 'Chemistry']
print(courses[0])
print(courses[1])

# Access last element
print(courses[len(courses)-1]) # OR
print(courses[-1])
# Out:
# History
# Math
# Chemistry
# Chemistry

# %%
courses = ['History', 'Math', 'Physics', 'Chemistry']
print(courses[1:3]) # From range 1 to 2 (Not 3 because second index is exclusive)
# Out:
# ['Math', 'Physics']

# %%
courses = ['History', 'Math', 'Physics', 'Chemistry']

# Append Element
courses.append("ComputerScience")
print(courses)

# Remove Element
courses.remove("ComputerScience")
print(courses)

# Insert Element at specific position
courses.insert(1, "English")
print(courses)
# Out:
# ['History', 'Math', 'Physics', 'Chemistry', 'ComputerScience']
# ['History', 'Math', 'Physics', 'Chemistry']
# ['History', 'English', 'Math', 'Physics', 'Chemistry']

# %%
courses = ['History', 'Math', 'Physics', 'Chemistry']

# Insert Elements from another list
courses_2 = ['Art', "Education"]
courses.extend(courses_2)
print(courses)
# Out:
# ['History', 'Math', 'Physics', 'Chemistry', 'Art', 'Education']

# %%
courses = ['History', 'Math', 'Physics', 'Chemistry']

# Pop Element from the end
courses.pop()
print(courses)
# Out:
# ['History', 'Math', 'Physics']

# %%
courses = ['History', 'Math', 'Physics', 'Chemistry']

# Reverse 
courses.reverse()
print(courses)
# Out:
# ['Chemistry', 'Physics', 'Math', 'History']

# %%
# Sort
# Ascending Order
nums = [5,1,8,3,9,4,6,2,7]
nums.sort()
print(nums)

# Descending Order
nums.sort(reverse=True)
print(nums)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# [9, 8, 7, 6, 5, 4, 3, 2, 1]
