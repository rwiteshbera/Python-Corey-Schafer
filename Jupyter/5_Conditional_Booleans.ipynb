# %%
language = 'Python'

if language == 'Python':
    print('Statement is True')
# Out:
# Statement is True

# %%
age = 19
if (age >= 18):
    print("You are eligible for vote.")
else: 
    print("You cannot vote.")
# Out:
# You are eligible for vote.

# %%
language = 'Java'
if language == 'Python':
    print('Language is Python')
elif language == 'Java':
    print('Language is Java')
else:
    print('No Match')
# Out:
# Language is Java

# %%
# Boolean Operations # And
user = 'Admin'
logged_in = True

if user == 'Admin' and logged_in:
    print('Admin Page')
else:
    prinnt('Bad Credentials')
# Out:
# Admin Page

# %%
# Boolean Operations # Or
user = 'Admin'
logged_in = False

if user == 'Admin' or logged_in:
    print('Admin Page')
else:
    prinnt('Bad Credentials')
# Out:
# Admin Page

# %%
log_in = True
if not log_in:
    print('Please login')
else:
    print('Log out')
# Out:
# Log out

# %%
a = [1,2,3]
b = [1,2,3]

print(id(a)) # Return the identity of object
print(id(b))
print(a is b) # Return false because these two are different objects.
# Out:
# 140655884552256
# 140655884551552
# False
